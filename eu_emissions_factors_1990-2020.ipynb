# %%
import pandas as pd

file = "EU_Emissions_Factors_1990-2020.xlsx"
xls = pd.ExcelFile(file)
xls.sheet_names
# Out:
# ['Read Me',
#  'Table 1_EU_IPCC_CO2',
#  'Table 2_EU_IPCC_GHG',
#  'Table 3_EU_LCA_GHG',
#  'Table 4_Neighbourhood_IPCC_CO2',
#  'Table 5_Neighbourhood_IPCC_GHG',
#  'Table 6_ Neighbourhood_LCA_GHG',
#  'Table 7_ROW_IPCC_CO2',
#  'Table 8_ROW_IPCC_GHG_FAR',
#  'Table 9_ROW_IPCC_GHG_SAR']

# %%
df1 = xls.parse("Table 1_EU_IPCC_CO2", skiprows=[0])
df1 = df1.rename(columns={"Unnamed: 0": "Country"})
df1.head()
# Out:
#     Country      1990      1991      1992      1993      1994      1995  \
# 0   Austria  0.282565  0.283317  0.223981  0.212675  0.233160  0.252197
# 1   Belgium  0.430454  0.409170  0.384663  0.389436  0.400656  0.393061
# 2  Bulgaria  0.859575  0.790064  0.903164  0.946473  0.860871  0.812136
# 3   Croatia  0.252621  0.180909  0.328778  0.358223  0.204611  0.239376
# 4    Cyprus  0.944069  0.935889  0.969691  0.949345  0.946427  0.943942
#
#        1996      1997      1998  ...      2011      2012      2013      2014  \
# 0  0.260933  0.261085  0.229107  ...  0.216983  0.179483  0.164288  0.142427
# 1  0.372093  0.339801  0.363718  ...  0.217679  0.215584  0.189001  0.179608
# 2  0.760778  0.895535  0.910891  ...  1.049628  0.899799  0.774450  0.826902
# 3  0.254590  0.274446  0.337196  ...  0.232320  0.215131  0.205675  0.176906
# 4  0.965809  0.984737  0.985709  ...  0.786831  0.799328  0.716285  0.733772
#
#        2015      2016      2017      2018      2019      2020
# ...

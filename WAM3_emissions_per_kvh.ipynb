# %%
import pandas as pd

df = pd.read_csv("WAM3 Interpolated Energy Mix.csv")
df.set_index("Rok", inplace=True)
df
# Out:
#                             2014         2015         2016         2017  \
# Rok
# Jaderné (JE)          4290.00000   4290.00000   4290.00000   4290.00000
# Parní (PE)           10836.70440  10741.85200  10849.97500  11075.52400
# Vodní (VE)            1091.04920   1094.98050   1100.19060   1112.26110
# Přečerpávací (PVE)    1171.50000   1171.50000   1171.50000   1171.50000
# Větrné (VTE)           278.19090    282.18590    282.15490    308.20740
# Fotovoltaické (FVE)   2076.79442   2078.25037   2075.66434   2076.62602
# Plynové (PLE)         2196.66900   2218.87800   2237.49200   2259.48700
#
#                             2018         2019         2020        2021  \
# Rok
# Jaderné (JE)          4290.00000   4290.00000   4290.00000  4290.00000
# Parní (PE)           11075.44200  10729.86900  10058.84800  9527.69500
# Vodní (VE)            1112.51960   1113.20809   1113.91253  1114.63113
# Přečerpávací (PVE)    1171.50000   1171.50000   1171.50000  1171.50000
# ...

# %%
df = df / df.sum(axis=0)
df
# Out:
#                          2014      2015      2016      2017      2018  \
# Rok
# Jaderné (JE)         0.195525  0.196091  0.194938  0.192432  0.192355
# Parní (PE)           0.493904  0.490997  0.493024  0.496803  0.496600
# Vodní (VE)           0.049727  0.050050  0.049993  0.049891  0.049883
# Přečerpávací (PVE)   0.053393  0.053548  0.053233  0.052549  0.052528
# Větrné (VTE)         0.012679  0.012898  0.012821  0.013825  0.014201
# Fotovoltaické (FVE)  0.094654  0.094994  0.094318  0.093149  0.092455
# Plynové (PLE)        0.100118  0.101422  0.101672  0.101351  0.101980
#
#                          2019      2020      2021      2022      2023  \
# Rok
# Jaderné (JE)         0.194874  0.200669  0.205483  0.206189  0.205352
# Parní (PE)           0.487405  0.470513  0.456360  0.452553  0.441444
# Vodní (VE)           0.050568  0.052104  0.053389  0.053521  0.053252
# Přečerpávací (PVE)   0.053215  0.054798  0.056113  0.056305  0.056077
# ...

# %%
emmissions_per_kwh = [0.005, 0.9, 0, 0, 0.00464, 0.058, 0.5]

# %%
df = df.multiply(emmissions_per_kwh, axis=0)
df
# Out:
#                          2014      2015      2016      2017      2018  \
# Rok
# Jaderné (JE)         0.000978  0.000980  0.000975  0.000962  0.000962
# Parní (PE)           0.444514  0.441897  0.443722  0.447122  0.446940
# Vodní (VE)           0.000000  0.000000  0.000000  0.000000  0.000000
# Přečerpávací (PVE)   0.000000  0.000000  0.000000  0.000000  0.000000
# Větrné (VTE)         0.000059  0.000060  0.000059  0.000064  0.000066
# Fotovoltaické (FVE)  0.005490  0.005510  0.005470  0.005403  0.005362
# Plynové (PLE)        0.050059  0.050711  0.050836  0.050676  0.050990
#
#                          2019      2020      2021      2022      2023  \
# Rok
# Jaderné (JE)         0.000974  0.001003  0.001027  0.001031  0.001027
# Parní (PE)           0.438664  0.423462  0.410724  0.407298  0.397300
# Vodní (VE)           0.000000  0.000000  0.000000  0.000000  0.000000
# Přečerpávací (PVE)   0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
annual_emmissions = df.sum(axis=0)
annual_emmissions
# Out:
# 2014    0.501099
# 2015    0.499158
# 2016    0.501063
# 2017    0.504227
# 2018    0.504320
# 2019    0.497428
# 2020    0.484564
# 2021    0.473826
# 2022    0.471351
# 2023    0.462743
# 2024    0.445586
# 2025    0.420354
# 2026    0.387730
# 2027    0.348563
# 2028    0.303808
# 2029    0.254482
# 2030    0.201608
# dtype: float64

# %%
annual_emmissions.plot(y=range(0, 1), title="Emissions per kwh", ylim=[0, 1])
# Out:
# <AxesSubplot: title={'center': 'Emissions per kwh'}>

# %%
annual_emmissions.to_csv("WAM3 Annual Emmissions Development.csv", index=True)

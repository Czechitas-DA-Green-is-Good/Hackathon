# %%
import pandas as pd

df = pd.read_csv("Interpolated Energy Mix.csv")
df
# Out:
#                    Rok         2014         2015         2016         2017  \
# 0         Jaderné (JE)   4290.00000   4290.00000   4290.00000   4290.00000
# 1           Parní (PE)  10836.70440  10741.85200  10849.97500  11075.52400
# 2           Vodní (VE)   1091.04920   1094.98050   1100.19060   1112.26110
# 3   Přečerpávací (PVE)   1171.50000   1171.50000   1171.50000   1171.50000
# 4         Větrné (VTE)    278.19090    282.18590    282.15490    308.20740
# 5  Fotovoltaické (FVE)   2076.79442   2078.25037   2075.66434   2076.62602
# 6              Plynové   2196.66900   2218.87800   2237.49200   2259.48700
#
#           2018         2019         2020        2021        2022         2023  \
# 0   4290.00000   4290.00000   4290.00000  4290.00000  4290.00000  4290.000000
# 1  11075.44200  10729.86900  10058.84800  9527.69500  9415.89700  9285.924263
# 2   1112.51960   1113.20809   1113.91253  1114.63113  1113.57568  1112.480340
# ...

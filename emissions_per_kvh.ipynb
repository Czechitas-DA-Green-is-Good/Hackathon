# %%
import pandas as pd

df = pd.read_csv("Interpolated Energy Mix.csv")
df.set_index("Rok", inplace=True)
df
# Out:
#                             2014         2015         2016         2017  \
# Rok
# Jaderné (JE)          4290.00000   4290.00000   4290.00000   4290.00000
# Parní (PE)           10836.70440  10741.85200  10849.97500  11075.52400
# Vodní (VE)            1091.04920   1094.98050   1100.19060   1112.26110
# Přečerpávací (PVE)    1171.50000   1171.50000   1171.50000   1171.50000
# Větrné (VTE)           278.19090    282.18590    282.15490    308.20740
# Fotovoltaické (FVE)   2076.79442   2078.25037   2075.66434   2076.62602
# Plynové               2196.66900   2218.87800   2237.49200   2259.48700
#
#                             2018         2019         2020        2021  \
# Rok
# Jaderné (JE)          4290.00000   4290.00000   4290.00000  4290.00000
# Parní (PE)           11075.44200  10729.86900  10058.84800  9527.69500
# Vodní (VE)            1112.51960   1113.20809   1113.91253  1114.63113
# Přečerpávací (PVE)    1171.50000   1171.50000   1171.50000  1171.50000
# ...

# %%
df = df / df.sum(axis=0)

# %%
emmissions_per_kwh = [0.005, 0.9, 0, 0, 0.00464, 0.058, 0.5]

# %%
df = df.multiply(emmissions_per_kwh, axis=0)
df
# Out:
#                              2014          2015          2016          2017  \
# Rok
# Jaderné (JE)         2.444065e-08  2.451132e-08  2.436727e-08  2.405398e-08
# Parní (PE)           3.600561e-01  3.579366e-01  3.594147e-01  3.621692e-01
# Vodní (VE)           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Přečerpávací (PVE)   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Větrné (VTE)         1.266608e-09  1.288513e-09  1.280800e-09  1.381073e-09
# Fotovoltaické (FVE)  1.846813e-05  1.853452e-05  1.840266e-05  1.817448e-05
# Plynové              1.251469e-02  1.267777e-02  1.270899e-02  1.266892e-02
#
#                              2018          2019          2020          2021  \
# Rok
# Jaderné (JE)         2.404434e-08  2.435919e-08  2.508366e-08  2.568541e-08
# Parní (PE)           3.620213e-01  3.553182e-01  3.430042e-01  3.326861e-01
# Vodní (VE)           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
annual_emmissions = df.sum(axis=0)
annual_emmissions
# Out:
# 2014    0.501099
# 2015    0.499158
# 2016    0.501063
# 2017    0.504227
# 2018    0.504320
# 2019    0.497428
# 2020    0.484564
# 2021    0.473826
# 2022    0.471351
# 2023    0.466487
# 2024    0.457296
# 2025    0.443911
# 2026    0.426523
# 2027    0.405379
# 2028    0.380771
# 2029    0.353027
# 2030    0.322499
# dtype: float64

# %%
annual_emmissions.plot(y=range(0, 1), title="Emmissions per kwh", ylim=[0, 1])
# Out:
# <AxesSubplot: title={'center': 'Emmissions per kwh'}>

# %%
annual_emmissions.to_csv("Annual Emmissions Development.csv", index=True)
